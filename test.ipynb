# %%
from jose import jwt
from datetime import datetime, timedelta

def create_access_token(data: dict):
    to_encode = data.copy()
    expire = datetime.utcnow() + timedelta(minutes=15)
    to_encode.update({"exp": expire})
    encoded_jwt = jwt.encode(to_encode, "dasfdasf", algorithm="HS256")
    return encoded_jwt

create_access_token({"user":"Gleb"})
# Out:
# /var/folders/7l/ghx4krkd6rbcfvjfly0r0n580000gn/T/ipykernel_55877/3766514151.py:6: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   expire = datetime.utcnow() + timedelta(minutes=15)
# 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJ1c2VyIjoiR2xlYiIsImV4cCI6MTc2MzM1Mzk2Mn0.H8_BBQcpiB5Exv66Bp59ka6zvqYO7Pl-p7hrtThPCkk'
